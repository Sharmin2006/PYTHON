# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharmin2006/PYTHON/blob/main/11th_july.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a,b=10,20
if(a>b):
  print("T")
else:
  print(bool(""))
# Out:
# False

# %%
c = 0 + 0j
print(c,'is',bool(c))
num = 99
print(num, 'is', bool(num))
val = None
print(val,'is',bool(val))
val = True
print(val,'is',bool(val))
# empty string
str = ''
print(str,'is',bool(str))
str = 'Hello'
print(str,'is',bool(str))
# Out:
# 0j is False
# 99 is True
# None is False
# True is True
#  is False
# Hello is True

# %%
def song():
  print("This is 1st line")
  song()
song()
# Out:
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# This is 1st line
# ...

# %%
def numbers():
  i=-1
  while(i<=0):
    print(i)
    i=i-1


numbers()
# Out:
# Streaming output truncated to the last 5000 lines.
# -4649023
# -4649024
# -4649025
# -4649026
# -4649027
# -4649028
# -4649029
# -4649030
# -4649031
# -4649032
# -4649033
# -4649034
# -4649035
# -4649036
# -4649037
# -4649038
# -4649039
# -4649040
# -4649041
# -4649042
# -4649043
# -4649044
# -4649045
# -4649046
# -4649047
# -4649048
# -4649049
# -4649050
# -4649051
# -4649052
# -4649053
# -4649054
# -4649055
# -4649056
# -4649057
# -4649058
# -4649059
# -4649060
# -4649061
# -4649062
# -4649063
# -4649064
# -4649065
# -4649066
# -4649067
# -4649068
# -4649069
# -4649070
# -4649071
# -4649072
# -4649073
# -4649074
# -4649075
# -4649076
# -4649077
# -4649078
# -4649079
# -4649080
# -4649081
# -4649082
# -4649083
# -4649084
# -4649085
# -4649086
# -4649087
# -4649088
# -4649089
# -4649090
# -4649091
# -4649092
# -4649093
# -4649094
# -4649095
# -4649096
# -4649097
# -4649098
# -4649099
# -4649100
# -4649101
# -4649102
# -4649103
# -4649104
# -4649105
# -4649106
# -4649107
# -4649108
# ...

# %%
def numbers():
  i=1
  while(i>0):
    print(i)
    i=i+1
numbers()
# Out:
# Streaming output truncated to the last 5000 lines.
# 15795832
# 15795833
# 15795834
# 15795835
# 15795836
# 15795837
# 15795838
# 15795839
# 15795840
# 15795841
# 15795842
# 15795843
# 15795844
# 15795845
# 15795846
# 15795847
# 15795848
# 15795849
# 15795850
# 15795851
# 15795852
# 15795853
# 15795854
# 15795855
# 15795856
# 15795857
# 15795858
# 15795859
# 15795860
# 15795861
# 15795862
# 15795863
# 15795864
# 15795865
# 15795866
# 15795867
# 15795868
# 15795869
# 15795870
# 15795871
# 15795872
# 15795873
# 15795874
# 15795875
# 15795876
# 15795877
# 15795878
# 15795879
# 15795880
# 15795881
# 15795882
# 15795883
# 15795884
# 15795885
# 15795886
# 15795887
# 15795888
# 15795889
# 15795890
# 15795891
# 15795892
# 15795893
# 15795894
# 15795895
# 15795896
# 15795897
# 15795898
# 15795899
# 15795900
# 15795901
# 15795902
# 15795903
# 15795904
# 15795905
# 15795906
# 15795907
# 15795908
# 15795909
# 15795910
# 15795911
# 15795912
# 15795913
# 15795914
# 15795915
# 15795916
# 15795917
# ...

# %%
def printstar():
  for i in L1:
    print("*"*i)
L1=[1,2,3,4,5]
printstar()
# Out:
# *
# **
# ***
# ****
# *****
